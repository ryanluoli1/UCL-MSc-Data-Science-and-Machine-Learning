# %% [markdown]
# ## Training Results Analysis

# %%
import os
import csv
import pickle

import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/SNLP Group Project')

# %%
classes = np.array(['angry', 'excited', 'happy', 'sad', 'frustrated', 'neutral', 'surprise'])

# %% [markdown]
# ## Self-Attention

# %%
metrics_sa = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa, valid_uwa_sa, valid_wf1_sa, valid_uwf1_sa, valid_cm_sa = [], [], [], [], []
test_wa_sa, test_uwa_sa, test_wf1_sa, test_uwf1_sa, test_cm_sa = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa.append(valid_metrics['wa'][idx])
    valid_uwa_sa.append(valid_metrics['uwa'][idx])
    valid_wf1_sa.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa.append(valid_metrics['uwf1'][idx])
    valid_cm_sa.append(valid_metrics['cm'][idx])
    test_wa_sa.append(test_metrics['wa'][idx])
    test_uwa_sa.append(test_metrics['uwa'][idx])
    test_wf1_sa.append(test_metrics['wf1'][idx])
    test_uwf1_sa.append(test_metrics['uwf1'][idx])
    test_cm_sa.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Self-Attention CLS

# %%
metrics_sa_cls = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results CLS/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results CLS/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_cls.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa_cls, valid_uwa_sa_cls, valid_wf1_sa_cls, valid_uwf1_sa_cls, valid_cm_sa_cls = [], [], [], [], []
test_wa_sa_cls, test_uwa_sa_cls, test_wf1_sa_cls, test_uwf1_sa_cls, test_cm_sa_cls = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_cls:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_cls.append(valid_metrics['wa'][idx])
    valid_uwa_sa_cls.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_cls.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_cls.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_cls.append(valid_metrics['cm'][idx])
    test_wa_sa_cls.append(test_metrics['wa'][idx])
    test_uwa_sa_cls.append(test_metrics['uwa'][idx])
    test_wf1_sa_cls.append(test_metrics['wf1'][idx])
    test_uwf1_sa_cls.append(test_metrics['uwf1'][idx])
    test_cm_sa_cls.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Cross-Attention Model

# %%
metrics_ca = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results/valid_metrics_ca_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results/test_metrics_ca_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_ca = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_ca = pickle.load(f)
    metrics_ca.append([valid_metrics_ca, test_metrics_ca])

# %%
valid_wa_ca, valid_uwa_ca, valid_wf1_ca, valid_uwf1_ca, valid_cm_ca = [], [], [], [], []
test_wa_ca, test_uwa_ca, test_wf1_ca, test_uwf1_ca, test_cm_ca = [], [], [], [], []

for valid_metrics, test_metrics in metrics_ca:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_ca.append(valid_metrics['wa'][idx])
    valid_uwa_ca.append(valid_metrics['uwa'][idx])
    valid_wf1_ca.append(valid_metrics['wf1'][idx])
    valid_uwf1_ca.append(valid_metrics['uwf1'][idx])
    valid_cm_ca.append(valid_metrics['cm'][idx])
    test_wa_ca.append(test_metrics['wa'][idx])
    test_uwa_ca.append(test_metrics['uwa'][idx])
    test_wf1_ca.append(test_metrics['wf1'][idx])
    test_uwf1_ca.append(test_metrics['uwf1'][idx])
    test_cm_ca.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Cross-Attention CLS

# %%
metrics_ca_cls = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results CLS/valid_metrics_ca_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results CLS/test_metrics_ca_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_ca = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_ca = pickle.load(f)
    metrics_ca_cls.append([valid_metrics_ca, test_metrics_ca])

# %%
valid_wa_ca_cls, valid_uwa_ca_cls, valid_wf1_ca_cls, valid_uwf1_ca_cls, valid_cm_ca_cls = [], [], [], [], []
test_wa_ca_cls, test_uwa_ca_cls, test_wf1_ca_cls, test_uwf1_ca_cls, test_cm_ca_cls = [], [], [], [], []

for valid_metrics, test_metrics in metrics_ca_cls:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_ca_cls.append(valid_metrics['wa'][idx])
    valid_uwa_ca_cls.append(valid_metrics['uwa'][idx])
    valid_wf1_ca_cls.append(valid_metrics['wf1'][idx])
    valid_uwf1_ca_cls.append(valid_metrics['uwf1'][idx])
    valid_cm_ca_cls.append(valid_metrics['cm'][idx])
    test_wa_ca_cls.append(test_metrics['wa'][idx])
    test_uwa_ca_cls.append(test_metrics['uwa'][idx])
    test_wf1_ca_cls.append(test_metrics['wf1'][idx])
    test_uwf1_ca_cls.append(test_metrics['uwf1'][idx])
    test_cm_ca_cls.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Text Only

# %%
metrics_sa_text = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results Text/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results Text/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_text.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa_text, valid_uwa_sa_text, valid_wf1_sa_text, valid_uwf1_sa_text, valid_cm_sa_text = [], [], [], [], []
test_wa_sa_text, test_uwa_sa_text, test_wf1_sa_text, test_uwf1_sa_text, test_cm_sa_text = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_text:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_text.append(valid_metrics['wa'][idx])
    valid_uwa_sa_text.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_text.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_text.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_text.append(valid_metrics['cm'][idx])
    test_wa_sa_text.append(test_metrics['wa'][idx])
    test_uwa_sa_text.append(test_metrics['uwa'][idx])
    test_wf1_sa_text.append(test_metrics['wf1'][idx])
    test_uwf1_sa_text.append(test_metrics['uwf1'][idx])
    test_cm_sa_text.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Audio Only

# %%
metrics_sa_audio = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results Audio/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results Audio/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_audio.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa_audio, valid_uwa_sa_audio, valid_wf1_sa_audio, valid_uwf1_sa_audio, valid_cm_sa_audio = [], [], [], [], []
test_wa_sa_audio, test_uwa_sa_audio, test_wf1_sa_audio, test_uwf1_sa_audio, test_cm_sa_audio = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_audio:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_audio.append(valid_metrics['wa'][idx])
    valid_uwa_sa_audio.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_audio.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_audio.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_audio.append(valid_metrics['cm'][idx])
    test_wa_sa_audio.append(test_metrics['wa'][idx])
    test_uwa_sa_audio.append(test_metrics['uwa'][idx])
    test_wf1_sa_audio.append(test_metrics['wf1'][idx])
    test_uwf1_sa_audio.append(test_metrics['uwf1'][idx])
    test_cm_sa_audio.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Text Mean

# %%
metrics_sa_text_mean = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results Text New/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results Text New/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_text_mean.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa_text_mean, valid_uwa_sa_text_mean, valid_wf1_sa_text_mean, valid_uwf1_sa_text_mean, valid_cm_sa_text_mean = [], [], [], [], []
test_wa_sa_text_mean, test_uwa_sa_text_mean, test_wf1_sa_text_mean, test_uwf1_sa_text_mean, test_cm_sa_text_mean = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_text_mean:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_text_mean.append(valid_metrics['wa'][idx])
    valid_uwa_sa_text_mean.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_text_mean.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_text_mean.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_text_mean.append(valid_metrics['cm'][idx])
    test_wa_sa_text_mean.append(test_metrics['wa'][idx])
    test_uwa_sa_text_mean.append(test_metrics['uwa'][idx])
    test_wf1_sa_text_mean.append(test_metrics['wf1'][idx])
    test_uwf1_sa_text_mean.append(test_metrics['uwf1'][idx])
    test_cm_sa_text_mean.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Text CLS

# %%
metrics_sa_text_cls = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results Text CLS/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results Text CLS/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_text_cls.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa_text_cls, valid_uwa_sa_text_cls, valid_wf1_sa_text_cls, valid_uwf1_sa_text_cls, valid_cm_sa_text_cls = [], [], [], [], []
test_wa_sa_text_cls, test_uwa_sa_text_cls, test_wf1_sa_text_cls, test_uwf1_sa_text_cls, test_cm_sa_text_cls = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_text_cls:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_text_cls.append(valid_metrics['wa'][idx])
    valid_uwa_sa_text_cls.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_text_cls.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_text_cls.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_text_cls.append(valid_metrics['cm'][idx])
    test_wa_sa_text_cls.append(test_metrics['wa'][idx])
    test_uwa_sa_text_cls.append(test_metrics['uwa'][idx])
    test_wf1_sa_text_cls.append(test_metrics['wf1'][idx])
    test_uwf1_sa_text_cls.append(test_metrics['uwf1'][idx])
    test_cm_sa_text_cls.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Audio Mean

# %%
metrics_sa_audio_mean = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results Audio/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results Audio/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_audio_mean.append([valid_metrics_sa, test_metrics_sa])

# %%
valid_wa_sa_audio_mean, valid_uwa_sa_audio_mean, valid_wf1_sa_audio_mean, valid_uwf1_sa_audio_mean, valid_cm_sa_audio_mean = [], [], [], [], []
test_wa_sa_audio_mean, test_uwa_sa_audio_mean, test_wf1_sa_audio_mean, test_uwf1_sa_audio_mean, test_cm_sa_audio_mean = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_audio:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_audio_mean.append(valid_metrics['wa'][idx])
    valid_uwa_sa_audio_mean.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_audio_mean.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_audio_mean.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_audio_mean.append(valid_metrics['cm'][idx])
    test_wa_sa_audio_mean.append(test_metrics['wa'][idx])
    test_uwa_sa_audio_mean.append(test_metrics['uwa'][idx])
    test_wf1_sa_audio_mean.append(test_metrics['wf1'][idx])
    test_uwf1_sa_audio_mean.append(test_metrics['uwf1'][idx])
    test_cm_sa_audio_mean.append(test_metrics['cm'][idx])

# %% [markdown]
# ## noSP

# %%
metrics_sa_noSP = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results noSP/valid_metrics_sa_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results noSP/test_metrics_sa_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_sa_noSP.append([valid_metrics_sa, test_metrics_sa])

valid_wa_sa_noSP, valid_uwa_sa_noSP, valid_wf1_sa_noSP, valid_uwf1_sa_noSP, valid_cm_sa_noSP = [], [], [], [], []
test_wa_sa_noSP, test_uwa_sa_noSP, test_wf1_sa_noSP, test_uwf1_sa_noSP, test_cm_sa_noSP = [], [], [], [], []

for valid_metrics, test_metrics in metrics_sa_noSP:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_sa_noSP.append(valid_metrics['wa'][idx])
    valid_uwa_sa_noSP.append(valid_metrics['uwa'][idx])
    valid_wf1_sa_noSP.append(valid_metrics['wf1'][idx])
    valid_uwf1_sa_noSP.append(valid_metrics['uwf1'][idx])
    valid_cm_sa_noSP.append(valid_metrics['cm'][idx])
    test_wa_sa_noSP.append(test_metrics['wa'][idx])
    test_uwa_sa_noSP.append(test_metrics['uwa'][idx])
    test_wf1_sa_noSP.append(test_metrics['wf1'][idx])
    test_uwf1_sa_noSP.append(test_metrics['uwf1'][idx])
    test_cm_sa_noSP.append(test_metrics['cm'][idx])

# %%
metrics_ca_noSP = []
for i in range(1,6):
    valid = sys.path[-1]+f"/Training Results noSP/valid_metrics_ca_0{i}.pkl"
    test = sys.path[-1]+f"/Training Results noSP/test_metrics_ca_0{i}.pkl"
    with open(valid, 'rb') as f:
        valid_metrics_sa = pickle.load(f)
    with open(test, 'rb') as f:
        test_metrics_sa = pickle.load(f)
    metrics_ca_noSP.append([valid_metrics_sa, test_metrics_sa])

valid_wa_ca_noSP, valid_uwa_ca_noSP, valid_wf1_ca_noSP, valid_uwf1_ca_noSP, valid_cm_ca_noSP = [], [], [], [], []
test_wa_ca_noSP, test_uwa_ca_noSP, test_wf1_ca_noSP, test_uwf1_ca_noSP, test_cm_ca_noSP = [], [], [], [], []

for valid_metrics, test_metrics in metrics_ca_noSP:
    idx = np.argmax(valid_metrics['uwa'])
    valid_wa_ca_noSP.append(valid_metrics['wa'][idx])
    valid_uwa_ca_noSP.append(valid_metrics['uwa'][idx])
    valid_wf1_ca_noSP.append(valid_metrics['wf1'][idx])
    valid_uwf1_ca_noSP.append(valid_metrics['uwf1'][idx])
    valid_cm_ca_noSP.append(valid_metrics['cm'][idx])
    test_wa_ca_noSP.append(test_metrics['wa'][idx])
    test_uwa_ca_noSP.append(test_metrics['uwa'][idx])
    test_wf1_ca_noSP.append(test_metrics['wf1'][idx])
    test_uwf1_ca_noSP.append(test_metrics['uwf1'][idx])
    test_cm_ca_noSP.append(test_metrics['cm'][idx])

# %% [markdown]
# ## Compare Test Results (old results, have some errors)

# %%
headers = ['Model', 'Unweighted Accuracy', 'Weigthed Accuracy', 'Weighted F1-Score', 'Unweighted F1-Score']

data = [['Self', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa), np.std(test_wa_sa)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa), np.std(test_uwa_sa)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa), np.std(test_wf1_sa)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa), np.std(test_uwf1_sa))],
        ['Cross', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_ca), np.std(test_wa_ca)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_ca), np.std(test_uwa_ca)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_ca), np.std(test_wf1_ca)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_ca), np.std(test_uwf1_ca))],
        [' ',' ',' ',' ',' '],
        ['Self-noSP', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa_noSP), np.std(test_wa_sa_noSP)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa_noSP), np.std(test_uwa_sa_noSP)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa_noSP), np.std(test_wf1_sa_noSP)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa_noSP), np.std(test_uwf1_sa_noSP))],
        ['Cross-noSP', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_ca_noSP), np.std(test_wa_ca_noSP)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_ca_noSP), np.std(test_uwa_ca_noSP)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_ca_noSP), np.std(test_wf1_ca_noSP)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_ca_noSP), np.std(test_uwf1_ca_noSP))],
        [' ',' ',' ',' ',' '],
        ['Self-CLS', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa_cls), np.std(test_wa_sa_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa_cls), np.std(test_uwa_sa_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa_cls), np.std(test_wf1_sa_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa_cls), np.std(test_uwf1_sa_cls))],
        ['Cross-CLS', 
         "{:.3f} ± {:.3f}".format(np.mean(valid_wa_ca_cls), np.std(valid_wa_ca_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(valid_uwa_ca_cls), np.std(valid_uwa_ca_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(valid_wf1_ca_cls), np.std(valid_wf1_ca_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(valid_uwf1_ca_cls), np.std(valid_uwf1_ca_cls))],
        [' ',' ',' ',' ',' '],
        ['Text Only', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa_text), np.std(test_wa_sa_text)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa_text), np.std(test_uwa_sa_text)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa_text), np.std(test_wf1_sa_text)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa_text), np.std(test_uwf1_sa_text))],
        ['Audio Only', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa_audio), np.std(test_wa_sa_audio)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa_audio), np.std(test_uwa_sa_audio)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa_audio), np.std(test_wf1_sa_audio)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa_audio), np.std(test_uwf1_sa_audio))],
        [' ',' ',' ',' ',' '],
        ['Text Mean', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa_text_mean), np.std(test_wa_sa_text_mean)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa_text_mean), np.std(test_uwa_sa_text_mean)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa_text_mean), np.std(test_wf1_sa_text_mean)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa_text_mean), np.std(test_uwf1_sa_text_mean))],
        ['Text CLS', 
         "{:.3f} ± {:.3f}".format(np.mean(test_wa_sa_text_cls), np.std(test_wa_sa_text_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwa_sa_text_cls), np.std(test_uwa_sa_text_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(test_wf1_sa_text_cls), np.std(test_wf1_sa_text_cls)),
         "{:.3f} ± {:.3f}".format(np.mean(test_uwf1_sa_text_cls), np.std(test_uwf1_sa_text_cls))],
                                  ]

print(tabulate(data, headers=headers, tablefmt='orgtbl', stralign="center"))
# Out:
# |   Model    |  Unweighted Accuracy  |  Weigthed Accuracy  |  Weighted F1-Score  |  Unweighted F1-Score  |
# |------------+-----------------------+---------------------+---------------------+-----------------------|
# |    Self    |     0.486 ± 0.020     |    0.522 ± 0.014    |    0.519 ± 0.016    |     0.488 ± 0.014     |
# |   Cross    |     0.477 ± 0.027     |    0.509 ± 0.009    |    0.509 ± 0.009    |     0.478 ± 0.024     |
# |            |                       |                     |                     |                       |
# | Self-noSP  |     0.464 ± 0.042     |    0.514 ± 0.022    |    0.507 ± 0.027    |     0.473 ± 0.046     |
# | Cross-noSP |     0.442 ± 0.021     |    0.498 ± 0.005    |    0.493 ± 0.005    |     0.448 ± 0.024     |
# |            |                       |                     |                     |                       |
# |  Self-CLS  |     0.461 ± 0.019     |    0.505 ± 0.008    |    0.504 ± 0.009    |     0.468 ± 0.021     |
# ...

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(12,12))

cm = np.sum(test_cm_sa, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', ax=axs[0][0], xticklabels=classes, yticklabels=classes)
axs[0][0].set_title('Self-Attention')
axs[0][0].set_ylabel('True Class')
axs[0][0].set_xlabel('Predicted Class')

cm = np.sum(test_cm_ca, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', ax=axs[0][1], xticklabels=classes, yticklabels=classes)
axs[0][1].set_title('Cross-Attention')
axs[0][1].set_ylabel('True Class')
axs[0][1].set_xlabel('Predicted Class')

cm = np.sum(test_cm_sa_text, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', ax=axs[1][0], xticklabels=classes, yticklabels=classes)
axs[1][0].set_title('Text Only')
axs[1][0].set_ylabel('True Class')
axs[1][0].set_xlabel('Predicted Class')

cm = np.sum(test_cm_sa_audio, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', ax=axs[1][1], xticklabels=classes, yticklabels=classes)
axs[1][1].set_title('Audio Only')
axs[1][1].set_ylabel('True Class')
axs[1][1].set_xlabel('Predicted Class')

cm = np.sum(test_cm_sa_cls, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', ax=axs[2][0], xticklabels=classes, yticklabels=classes)
axs[2][0].set_title('Self-CLS')
axs[2][0].set_ylabel('True Class')
axs[2][0].set_xlabel('Predicted Class')

cm = np.sum(test_cm_ca_cls, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', ax=axs[2][1], xticklabels=classes, yticklabels=classes)
axs[2][1].set_title('Cross-CLS')
axs[2][1].set_ylabel('True Class')
axs[2][1].set_xlabel('Predicted Class')

fig.suptitle('Confusion Matrices', fontsize=16)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

cm = np.sum(test_cm_sa, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', cbar=False, ax=axs[0], xticklabels=classes, yticklabels=classes)
axs[0].set_title('Self-MHA', fontsize=14)
axs[0].set_xticklabels(classes, rotation=0)
axs[0].set_yticklabels(classes, rotation=0)
axs[0].set_ylabel('True Class', fontsize=14)

cm = np.sum(test_cm_ca, axis=0)
normalized_cm = cm / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(normalized_cm, annot=True, fmt=".3f", cmap='Blues', cbar=False, ax=axs[1], xticklabels=classes, yticklabels=[])
axs[1].set_title('Cross-MHA', fontsize=14)
axs[1].set_xticklabels(classes, rotation=0)

fig.supxlabel('Predicted Class', fontsize=14)
fig.suptitle('Confusion Matrices', fontsize=18)
plt.tight_layout()
plt.show()
